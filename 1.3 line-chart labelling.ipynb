# %%
import numpy as np
from matplotlib import pyplot as plt

#define array
x= np.arange(1,11)
y= 2*x

#graph
plt.plot(x,y)


#labelling
plt.title("Line plot")
plt.xlabel("x-label")
plt.ylabel("y-label")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
