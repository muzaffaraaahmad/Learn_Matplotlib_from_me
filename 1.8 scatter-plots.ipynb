# %% [markdown]
# when you want to understand the categorical data, we use the bar plot

# %%
import numpy as np
from matplotlib import pyplot as plt



x=[10,20,30,40,50,60]
a=[1,2,5,5,7,4]

# %%
plt.scatter(x,a)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# changing color and points

# %%
x=[10,20,30,40,50,60]
a=[1,2,5,5,7,4]
plt.scatter(x,a,marker="*", color="r",s=100)  #size=100
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
