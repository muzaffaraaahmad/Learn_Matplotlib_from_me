# %%
import numpy as np
from matplotlib import pyplot as plt

#define array
x= np.arange(1,11)
y= 2*x

#graph and give color and line astricks
plt.plot(x,y, color = "g", linestyle= ":", linewidth= 2 )
